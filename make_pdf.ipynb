# %%
from IPython.display import Markdown

from dreamai.rag import pdf_to_md_docs

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
chunks = pdf_to_md_docs("soccer.txt").chunks

# %%
Markdown(chunks[4]["text"])
# Out:
# **Ball In and Out of Play**: The ball is considered in play at all times unless it
# fully crosses the touchline or goal line, or play is stopped by the referee.
# 4. **Scoring**: A goal is scored when the entire ball crosses the goal line between
# the goalposts and under the crossbar.
# 5. **Offside**: A player is in an offside position if they are nearer to the
# opponent's goal line than both the ball and the second-last opponent when the ball is
# played to them by a teammate. (We'll cover this in more detail later.)
# 6. **Fouls**: Players are not allowed to kick, trip, charge, strike, or push an
# opponent. Doing so results in a free kick for the opposing team.
# 7. **Free Kicks
